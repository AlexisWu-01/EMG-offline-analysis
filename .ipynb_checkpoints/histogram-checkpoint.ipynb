# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
features = ['wl', 'mav', 'ssc', 'zc', 'var', 'sampen']
channels = ['ch1', 'ch2', 'ch3', 'ch4']

for ch in channels:
    for feature in features:
        col = f"{ch}_{feature}"
        
        # Plot histogram for each condition
        for label, group in df.groupby('Label'):
            label_name = ['rock', 'paper', 'scissors'][label - 1]  # Assumes Label values are 1, 2, 3
            plt.hist(group[col], bins="fd", alpha=0.8, label=label_name)
        
        # Add legend, labels, and title
        plt.legend(title='Condition')
        plt.xlabel('Value')
        plt.ylabel('Frequency')
        plt.title(f'Histogram of {ch} Feature: {feature}')
        
        # Show plot
        plt.show()
        plt.savefig(f"feature_plots/{ch}_{feature}.png")
